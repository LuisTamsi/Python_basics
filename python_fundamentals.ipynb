# %% [markdown]
# # 🐍 Python Fundamentals
# ### Variables • Data Types • Print/Input/Strings • Operators • Control Flow
#
# Run each cell, then complete the `# TODO` parts below it.

# %% [markdown]
# ---
# ## 1. Variables
# A variable is a **named container that holds a value**. Create one by assigning a value — no need to declare a type.
#
# ```python
# age = 21
# name = "Hyru"
# ```

# %%
# TODO: Create 3 variables about yourself, then print a sentence using all three

my_name = "Luis Miguel Tamsi"
my_age = 19
favorite_subject = "DevNet"

print(f"Hi, I'm {my_name}, I'm {my_age} years old, and I love {favorite_subject}.")
# Out:
# Hi, I'm Luis Miguel Tamsi, I'm 19 years old, and I love DevNet.

# %% [markdown]
# ---
# ## 2. Data Types
# Every value has a **type** that determines what you can do with it.
#
# | Type | Example |
# |---|---|
# | `int` | `21` |
# | `float` | `3.14` |
# | `str` | `"hello"` |
# | `bool` | `True` / `False` |
#
# Check a value's type with `type(x)`.

# %%
# TODO: Predict the type of each value BEFORE running, then uncomment to check

a = 21
b = 3.14
c = "hello"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))

# BONUS: try a + c below. Why does it break? Fix it with int(c)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ---
# ## 2b. Type Conversion
# You can convert a value from one type to another using `int()`, `float()`, `str()`, `bool()`.
#
# ```python
# num = "10"
# num = int(num)   # now it's an actual number, not text
# ```
#
# Common use: `input()` gives you a string, so you convert it before doing math.

# %%
# TODO: Fix the broken code below using type conversion

a = 10
b = 3.9
c = "5"

b = int(b)
c = int(c)

# Fix it here:
result = a + c
print(result)
# BONUS: convert 3.9 into an int. What happens to the decimal part?
print(b)
# Out:
# 15
# 3

# %% [markdown]
# ---
# ## 3. Print, Input & String Formatting
# - `print()` → shows output
# - `input()` → asks the user for text — **always returns a `str`**, even for numbers
# - **f-strings** → the clean way to combine variables into a sentence: `f"Hi {name}"`
#
# ```python
# name = input("What's your name? ")
# print(f"Hello, {name}!")
# ```

# %%
# TODO: Build a mini "About Me" generator

name = input("What's your name? ")
age = int(input("How old are you? "))   # this comes back as a STRING
hobby = input("What's your favorite hobby? ")

# 1. Print an f-string introduction using name, age, and hobby
print(f"My name is {name}, {age} years old my hobby is {hobby}")

# 2. BONUS: try age + 5 directly (it breaks). Fix it with int(age) + 5
print(age + 5)
# Out:
# My name is luis, 19 years old my hobby is codm
# 24

# %% [markdown]
# ---
# ## 4. Operators
# - **Arithmetic:** `+ - * / // % **`
# - **Comparison:** `== != > < >= <=` → always returns a `bool`
# - **Logical:** `and`, `or`, `not` → combine conditions

# %%
# TODO: Simple grade checker

score = 85
passing_score = 75

# 1. Check if the student passed (comparison operator)
passed = score > passing_score

# 2. Check if the score is even (modulo)
is_even = score % 2 == 0

# 3. Check if the student passed AND scored above 80 ('and')
honor_roll = score > passing_score and score > 80

print(passed)
print(bool(is_even))
print(honor_roll)
# Out:
# True
# False
# True

# %% [markdown]
# ---
# ## 5. Control Flow
# - **Conditionals** `if / elif / else` → choose a path based on a condition
# - **Loops** `for` (repeat a known number of times) / `while` (repeat until a condition changes)
#
# ```python
# if score >= 75:
#     print("Passed")
# else:
#     print("Failed")
# ```

# %%
# TODO: Build a simple "bouncer" program

age = 17

if age < 18:
    print("Minor")
else:
    print("Adult")



# 2. BONUS: use a for loop to count down from 5 to 1, then print "Doors open!"
i = 5
while i > 0:
  print(i)
  i -= 1

print("Doors open!")
# Out:
# Minor
# 5
# 4
# 3
# 2
# 1
# Doors open!

# %% [markdown]
# ---
# ## 🏗️ Final Challenge — pick ONE
# Must use: a variable, the correct data type, `input()`, an operator, and `if/elif/else`.

# %% [markdown]
# ### Option A — Number Guessing Game

# %%
secret_number = 7
guess = int(input("Guess a number: "))

# TODO: if/elif/else — tell the user if their guess is too high, too low, or correct
if guess == secret_number:
    print("Correct")
elif guess > secret_number:
    print("Guess to high")
elif guess < secret_number:
    print("Guess to low")
# Out:
# Guess to high

# %% [markdown]
# ### Option B — Simple Login Checker

# %%
correct_username = "admin"
correct_password = "python123"

# TODO: ask for username and password using input()
user_name = input("Username: ")
user_pass = input("Password: ")
# TODO: check both using 'and'
if user_name == correct_username and user_pass == correct_password:
    print("Access granted")
else:
    print("Access denied")
# TODO: print "Access granted" or "Access denied"
# Out:
# Access denied
